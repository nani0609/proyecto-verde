# %%
import pandas as pd

# Leer el archivo CSV
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AAVV por habitantes.csv')

# Mostrar los primeros 5 registros
df.head()
# Out:
#            comunas    sup AAVV m2 % AAVV x hab
# 0             BUIN      603984.88        7.34%
# 1  CALERA DE TANGO       29946.03        2.61%
# 2        CERRILLOS     1176964.65       14.58%
# 3      CERRO NAVIA  7.987.866.433        6.03%
# 4           COLINA     1115239.62        9.46%
